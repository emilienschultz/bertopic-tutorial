# %% [markdown]
# ```python
# from bertopic import BERTopic
#
# documents = [
#     "My cat is the cutest.",
#     "Offer your cat prenium food.",
#     "The Empire State building is 1,250 feet tall",
# ]
#
# topic_model = BERTopic()
# topic, _ = topic_model.fit_transform(documents)
# ```

# %% [markdown]
# # Open data and preprocess

# %%
import pandas as pd

df_raw = pd.read_csv("./data/theses-soutenues-curated.csv")
df_raw
# Out:
#                CI    year oai_set_specs  \
# 0            CI-0  2010.0       ddc:004
# 1            CI-1  2012.0       ddc:570
# 2            CI-2  2010.0       ddc:150
# 3            CI-3  2010.0       ddc:530
# 4            CI-4  2012.0       ddc:796
# ...           ...     ...           ...
# 164374  CI-164374  2011.0       ddc:330
# 164375  CI-164375  2017.0       ddc:530
# 164376  CI-164376  2011.0       ddc:610
# 164377  CI-164377  2012.0       ddc:840
# 164378  CI-164378  2014.0       ddc:590
#
#                                                 titres.en  \
# 0       ViSaGe project : VisageFS, a filesystem with a...
# 1       Neural basis of glaucoma : a new approach comb...
# 2       Richard Wagner and the Redemption's opera : co...
# 3       Investigation of temperature measurement of ma...
# 4                            Sociology of juvenile prison
# ...                                                   ...
# 164374                 Partial Ownerships and Competition
# 164375  New dynamics in doped fiber laser cavity : sel...
# 164376  Vectorization of siRNA targeting RET/PTC1 jonc...
# 164377  From the knowledge of China to the knowledge o...
# 164378  Consequences and predictable impacts of a majo...
#
#                                                resumes.en lang_res.en  \
# 0       Nowdays, the grid computing enables solutions ...          EN
# 1       Decreased visual motion sensitivity in early s...          EN
# 2       Richard Wagner's poetic and musical writing in...          EN
# 3       This work investigates the temperature measure...          EN
# 4       Researches in social sciences that deal with t...          EN
# ...                                                   ...         ...
# 164374  The literature is unanimous about the harmfuln...          EN
# 164375  Non-linear effects, which depend essentially o...          EN
# 164376  The papillary thyroid carcinoma (PTC) is the m...          EN
# 164377  Our research focuses on the relationships in V...          EN
# 164378  Urbanization and increasing transport infrastr...          EN
#
#                           topics.en  \
# 0                     POSIX (norme)
# 1                               NaN
# 2                               NaN
# 3                               NaN
# 4                               NaN
# ...                             ...
# 164374                  Concurrence
# 164375                          NaN
# 164376               Nanoparticules
# 164377  Segalen, Victor (1878-1919)
# 164378                          NaN
#
#                                                 titres.fr  \
# 0       Projet ViSaGe : VisageFS, systèmes de fichiers...
# 1       Bases neuronales du glaucome : une approche co...
# 2       Richard Wagner et l’Opéra de la Rédemption : c...
# 3       Contribution à la mesure de température des ma...
# 4       Faire sa peine à l'établissement pénitentiaire...
# ...                                                   ...
# 164374            Prises de Participations et Concurrence
# 164375  Nouvelles dynamiques en cavité laser à fibre d...
# 164376  Vectorisation de siRNA dirigés contre l'oncogè...
# 164377  De la connaissance de la Chine à la connaissan...
# 164378  Conséquences et impacts prévisibles d'une pert...
#
#                                                resumes.fr lang_res.fr  \
# 0       Les grilles informatiques permettent d'envisag...          FR
# 1       La diminution précoce de la sensibilité au mou...          FR
# 2       L’écriture poétique et musicale de Richard Wag...          FR
# 3       Le cadre de ces travaux concerne la mesure de ...          FR
# 4       Les recherches en sciences sociales s'intéress...          FR
# ...                                                   ...         ...
# 164374  La littérature est unanime quand à la nocivité...          FR
# 164375  Les effets non-linéaires dépendant essentielle...          FR
# 164376  Le cancer papillaire de la thyroïde (PTC) repr...          FR
# 164377  La recherche s’attache aux rapports dans l'œuv...          FR
# 164378  L'urbanisation et la construction d'infrastruc...          FR
#
#                                                 topics.fr swapped
# 0       Entrepôts de données||Langages de programmatio...     NaN
# 1             Poursuite oculaire||Glaucome à angle ouvert     NaN
# 2       Musique -- 19e siècle -- Thèmes, motifs||Psych...     NaN
# 3       Thermométrie||Pyrométrie||Choc (mécanique)||Ma...     NaN
# 4       Centres pour jeunes délinquants||Détention des...     NaN
# ...                                                   ...     ...
# 164374  Fusion d'entreprises||Offres publiques d'achat...     NaN
# 164375  Interféromètres||Techniques des impulsions (él...     NaN
# 164376  Nanomédecine||Squalène||Cancérogenèse||Petit A...     NaN
# 164377  Études chinoises||Théologie||Herméneutique||Li...     NaN
# 164378  Conservation des ressources (biologie)||Nîmes ...     NaN
#
# [164379 rows x 12 columns]

# %%
from transformers import AutoConfig 

model_name = "sentence-transformers/all-MiniLM-L6-v2"
config = AutoConfig.from_pretrained(model_name, trust_remote_code = True)
print(f"Context window size of the model {model_name}: {config.max_position_embeddings}")

model_name = "Alibaba-NLP/gte-multilingual-base"
config = AutoConfig.from_pretrained(model_name, trust_remote_code = True)
print(f"Context window size of the model {model_name}: {config.max_position_embeddings}")
# Out:
# Context window size of the model sentence-transformers/all-MiniLM-L6-v2: 512
# Context window size of the model Alibaba-NLP/gte-multilingual-base: 8192

# %%
df_raw["resumes.en.len"] = df_raw["resumes.en"].apply(len)
df_raw["resumes.fr.len"] = df_raw["resumes.fr"].apply(len)
df_raw.loc[:,["resumes.en.len", "resumes.fr.len"]].describe()
# Out:
#        resumes.en.len  resumes.fr.len
# count   164379.000000   164379.000000
# mean      1777.648082     1984.935119
# std        735.027732      802.720810
# min          1.000000        6.000000
# 25%       1324.000000     1508.000000
# 50%       1617.000000     1702.000000
# 75%       2080.000000     2362.000000
# max      12010.000000    12207.000000

# %%
from numpy import logical_and

valid_index = logical_and.reduce([
    df_raw["resumes.fr.len"] >= 1000,
    df_raw["resumes.fr.len"] <= 4000,
    df_raw["resumes.en.len"] >= 1000,
    df_raw["resumes.en.len"] <= 4000,
])

df = df_raw.loc[valid_index,:]
print(f"Proportion of the dataset preserved: {100 * len(df) / len(df_raw):.0f} %")
# Out:
# Proportion of the dataset preserved: 89 %

# %%
stratification_column = "year"
samples_per_stratum = 500
df_stratified = (
	df
	.groupby(stratification_column, as_index = False)
	.apply(lambda x : x.sample(n = samples_per_stratum), include_groups=True)
	.reset_index()
	.drop(["level_0", "level_1"], axis = 1)
)
print(f"Size of the dataset: {len(df_stratified)}")
# Out:
# Size of the dataset: 6500

# %%
df_stratified.to_csv("./data/theses-soutenues-curated-stratified.csv", index=False)

# %% [markdown]
# # Create a BERTopic instance, fit and transform

# %%
from bertopic import BERTopic
from sklearn.feature_extraction.text import CountVectorizer
from stopwordsiso import stopwords


language = "english" # or "french"
language_short = language[:2] # "en" or "fr"

docs = df_stratified[f"resumes.{language_short}"] # "resumes.en" or "resumes.fr"

vectorizer_model = CountVectorizer(
    stop_words = list(stopwords(language_short)),
    ngram_range = (1,1)
)

topic_model = BERTopic(
    embedding_model="sentence-transformers/all-MiniLM-L6-v2",
    language = language,
    vectorizer_model = vectorizer_model,
)
topic_model.fit(documents=docs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[21], line 21
#      11 vectorizer_model = CountVectorizer(
#      12     stop_words = list(stopwords(language_short)),
#      13     ngram_range = (1,1)
#      14 )
#      16 topic_model = BERTopic(
#      17     embedding_model="Alibaba-NLP/gte-multilingual-base",
#      18     language = language,
#      19     vectorizer_model = vectorizer_model,
#      20 )
# ---> 21 topic_model.fit(documents=docs)
#
# File /opt/miniconda3/envs/bertopic/lib/python3.11/site-packages/bertopic/_bertopic.py:387, in BERTopic.fit(self, documents, embeddings, images, y)
#     345 def fit(
#     346     self,
#     347     documents: List[str],
#    (...)    350     y: Union[List[int], np.ndarray] = None,
#     351 ):
#     352     """Fit the models on a collection of documents and generate topics.
#     353
#     354     Arguments:
#    (...)    385     ```
#     386     """
# --> 387     self.fit_transform(documents=documents, embeddings=embeddings, y=y, images=images)
#     388     return self
#
# File /opt/miniconda3/envs/bertopic/lib/python3.11/site-packages/bertopic/_bertopic.py:453, in BERTopic.fit_transform(self, documents, embeddings, images, y)
#     451 if embeddings is None:
#     452     logger.info("Embedding - Transforming documents to embeddings.")
# --> 453     self.embedding_model = select_backend(self.embedding_model, language=self.language, verbose=self.verbose)
#     454     embeddings = self._extract_embeddings(
#     455         documents.Document.values.tolist(),
#     456         images=images,
#     457         method="document",
#     458         verbose=self.verbose,
#     459     )
#     460     logger.info("Embedding - Completed \u2713")
#
# File /opt/miniconda3/envs/bertopic/lib/python3.11/site-packages/bertopic/backend/_utils.py:119, in select_backend(embedding_model, language, verbose)
#     116 if "sentence_transformers" in str(type(embedding_model)) or isinstance(embedding_model, str):
#     117     from ._sentencetransformers import SentenceTransformerBackend
# --> 119     return SentenceTransformerBackend(embedding_model)
#     121 # Hugging Face embeddings
#     122 if "transformers" and "pipeline" in str(type(embedding_model)):
#
# File /opt/miniconda3/envs/bertopic/lib/python3.11/site-packages/bertopic/backend/_sentencetransformers.py:63, in SentenceTransformerBackend.__init__(self, embedding_model, model2vec)
#      61     self.embedding_model = embedding_model
#      62 elif isinstance(embedding_model, str):
# ---> 63     self.embedding_model = SentenceTransformer(embedding_model)
#      64     self._hf_model = embedding_model
#      65 else:
#
# File /opt/miniconda3/envs/bertopic/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:327, in SentenceTransformer.__init__(self, model_name_or_path, modules, device, prompts, default_prompt_name, similarity_fn_name, cache_folder, trust_remote_code, revision, local_files_only, token, use_auth_token, truncate_dim, model_kwargs, tokenizer_kwargs, config_kwargs, model_card_data, backend)
#     309 has_modules = is_sentence_transformer_model(
#     310     model_name_or_path,
#     311     token,
#    (...)    314     local_files_only=local_files_only,
#     315 )
#     316 if (
#     317     has_modules
#     318     and self._get_model_type(
#    (...)    325     == self._model_config["model_type"]
#     326 ):
# --> 327     modules, self.module_kwargs = self._load_sbert_model(
#     328         model_name_or_path,
#     329         token=token,
#     330         cache_folder=cache_folder,
#     331         revision=revision,
#     332         trust_remote_code=trust_remote_code,
#     333         local_files_only=local_files_only,
#     334         model_kwargs=model_kwargs,
#     335         tokenizer_kwargs=tokenizer_kwargs,
#     336         config_kwargs=config_kwargs,
#     337     )
#     338 else:
#     339     modules = self._load_auto_model(
#     340         model_name_or_path,
#     341         token=token,
#    (...)    349         has_modules=has_modules,
#     350     )
#
# File /opt/miniconda3/envs/bertopic/lib/python3.11/site-packages/sentence_transformers/SentenceTransformer.py:2253, in SentenceTransformer._load_sbert_model(self, model_name_or_path, token, cache_folder, revision, trust_remote_code, local_files_only, model_kwargs, tokenizer_kwargs, config_kwargs)
#    2248         module = module_class.load(local_path)
#    2250 else:
#    2251     # Newer modules that support the new loading method are loaded with the new style
#    2252     # i.e. with many keyword arguments that can optionally be used by the modules
# -> 2253     module = module_class.load(
#    2254         model_name_or_path,
#    2255         # Loading-specific keyword arguments
#    2256         subfolder=module_config["path"],
#    2257         token=token,
#    2258         cache_folder=cache_folder,
#    2259         revision=revision,
#    2260         local_files_only=local_files_only,
#    2261         # Module-specific keyword arguments
#    2262         trust_remote_code=trust_remote_code,
#    2263         model_kwargs=model_kwargs,
#    2264         tokenizer_kwargs=tokenizer_kwargs,
#    2265         config_kwargs=config_kwargs,
#    2266         backend=self.backend,
#    2267     )
#    2269 modules[module_config["name"]] = module
#    2270 module_kwargs[module_config["name"]] = module_config.get("kwargs", [])
#
# File /opt/miniconda3/envs/bertopic/lib/python3.11/site-packages/sentence_transformers/models/Transformer.py:338, in Transformer.load(cls, model_name_or_path, subfolder, token, cache_folder, revision, local_files_only, trust_remote_code, model_kwargs, tokenizer_kwargs, config_kwargs, backend, **kwargs)
#     307 @classmethod
#     308 def load(
#     309     cls,
#    (...)    323     **kwargs,
#     324 ) -> Self:
#     325     init_kwargs = cls._load_init_kwargs(
#     326         model_name_or_path=model_name_or_path,
#     327         subfolder=subfolder,
#    (...)    336         backend=backend,
#     337     )
# --> 338     return cls(model_name_or_path=model_name_or_path, **init_kwargs)
#
# File /opt/miniconda3/envs/bertopic/lib/python3.11/site-packages/sentence_transformers/models/Transformer.py:86, in Transformer.__init__(self, model_name_or_path, max_seq_length, model_args, tokenizer_args, config_args, cache_dir, do_lower_case, tokenizer_name_or_path, backend)
#      83 if config_args is None:
#      84     config_args = {}
# ---> 86 config, is_peft_model = self._load_config(model_name_or_path, cache_dir, backend, config_args)
#      87 self._load_model(model_name_or_path, config, cache_dir, backend, is_peft_model, **model_args)
#      89 if max_seq_length is not None and "model_max_length" not in tokenizer_args:
#
# File /opt/miniconda3/envs/bertopic/lib/python3.11/site-packages/sentence_transformers/models/Transformer.py:151, in Transformer._load_config(self, model_name_or_path, cache_dir, backend, config_args)
#     147     from peft import PeftConfig
#     149     return PeftConfig.from_pretrained(model_name_or_path, **config_args, cache_dir=cache_dir), True
# --> 151 return AutoConfig.from_pretrained(model_name_or_path, **config_args, cache_dir=cache_dir), False
#
# File /opt/miniconda3/envs/bertopic/lib/python3.11/site-packages/transformers/models/auto/configuration_auto.py:1297, in AutoConfig.from_pretrained(cls, pretrained_model_name_or_path, **kwargs)
#    1295     else:
#    1296         upstream_repo = None
# -> 1297     trust_remote_code = resolve_trust_remote_code(
#    1298         trust_remote_code, pretrained_model_name_or_path, has_local_code, has_remote_code, upstream_repo
#    1299     )
#    1301 if has_remote_code and trust_remote_code:
#    1302     config_class = get_class_from_dynamic_module(
#    1303         class_ref, pretrained_model_name_or_path, code_revision=code_revision, **kwargs
#    1304     )
#
# File /opt/miniconda3/envs/bertopic/lib/python3.11/site-packages/transformers/dynamic_module_utils.py:747, in resolve_trust_remote_code(trust_remote_code, model_name, has_local_code, has_remote_code, error_message, upstream_repo)
#     744         _raise_timeout_error(None, None)
#     746 if has_remote_code and not has_local_code and not trust_remote_code:
# --> 747     raise ValueError(
#     748         f"{error_message} You can inspect the repository content at https://hf.co/{model_name}.\n"
#     749         f"Please pass the argument `trust_remote_code=True` to allow custom code to be run."
#     750     )
#     752 return trust_remote_code
#
# ValueError: Alibaba-NLP/new-impl You can inspect the repository content at https://hf.co/Alibaba-NLP/gte-multilingual-base.
# Please pass the argument `trust_remote_code=True` to allow custom code to be run.
